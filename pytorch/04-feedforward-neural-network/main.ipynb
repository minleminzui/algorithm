# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
input_size = 784
hidden_size = 500
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='../data', train=True, transform=transforms.ToTensor(), download=True)

test_dataset = torchvision.datasets.MNIST(root='../data', train=False, transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes) -> None:
      super(NeuralNet, self).__init__()
      self.fc1 = nn.Linear(input_size, hidden_size)
      self.relu = nn.ReLU()
      self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
      out = self.fc1(x)
      out = self.relu(out)
      out = self.fc2(out)
      return out
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
   for i, (images, labels) in enumerate(train_loader):
      # Move tensors to the configured device
      images = images.reshape(-1, 28*28).to(device)
      labels = labels.to(device)
      # Forward pass
      outputs = model(images)
      loss = criterion(outputs, labels)

      # Backward and optimize
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if (i + 1) % 100 == 0:
        print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
   correct = 0
   total = 0
   for images, labels in test_loader:
      images = images.reshape(-1, 28 * 28).to(device)
      labels = labels.to(device)
      outputs = model(images)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

      print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
  
# Save the model checkpoint
# torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Epoch [1/5], Step [100/600], Loss: 0.4381
# Epoch [1/5], Step [200/600], Loss: 0.4001
# Epoch [1/5], Step [300/600], Loss: 0.2167
# Epoch [1/5], Step [400/600], Loss: 0.1898
# Epoch [1/5], Step [500/600], Loss: 0.0899
# Epoch [1/5], Step [600/600], Loss: 0.1569
# Epoch [2/5], Step [100/600], Loss: 0.0918
# Epoch [2/5], Step [200/600], Loss: 0.1269
# Epoch [2/5], Step [300/600], Loss: 0.1596
# Epoch [2/5], Step [400/600], Loss: 0.0666
# Epoch [2/5], Step [500/600], Loss: 0.1490
# Epoch [2/5], Step [600/600], Loss: 0.0614
# Epoch [3/5], Step [100/600], Loss: 0.0578
# Epoch [3/5], Step [200/600], Loss: 0.0818
# Epoch [3/5], Step [300/600], Loss: 0.0436
# Epoch [3/5], Step [400/600], Loss: 0.0441
# Epoch [3/5], Step [500/600], Loss: 0.1322
# Epoch [3/5], Step [600/600], Loss: 0.0494
# Epoch [4/5], Step [100/600], Loss: 0.0276
# Epoch [4/5], Step [200/600], Loss: 0.0086
# Epoch [4/5], Step [300/600], Loss: 0.0197
# Epoch [4/5], Step [400/600], Loss: 0.0280
# Epoch [4/5], Step [500/600], Loss: 0.0335
# Epoch [4/5], Step [600/600], Loss: 0.0591
# Epoch [5/5], Step [100/600], Loss: 0.0300
# Epoch [5/5], Step [200/600], Loss: 0.0389
# Epoch [5/5], Step [300/600], Loss: 0.0558
# Epoch [5/5], Step [400/600], Loss: 0.0198
# Epoch [5/5], Step [500/600], Loss: 0.0591
# Epoch [5/5], Step [600/600], Loss: 0.0386
# Accuracy of the network on the 10000 test images: 100.0 %
# Accuracy of the network on the 10000 test images: 99.5 %
# Accuracy of the network on the 10000 test images: 99.0 %
# Accuracy of the network on the 10000 test images: 98.5 %
# Accuracy of the network on the 10000 test images: 98.2 %
# Accuracy of the network on the 10000 test images: 98.33333333333333 %
# Accuracy of the network on the 10000 test images: 98.14285714285714 %
# Accuracy of the network on the 10000 test images: 98.125 %
# Accuracy of the network on the 10000 test images: 97.88888888888889 %
# Accuracy of the network on the 10000 test images: 97.5 %
# Accuracy of the network on the 10000 test images: 97.54545454545455 %
# Accuracy of the network on the 10000 test images: 97.5 %
# Accuracy of the network on the 10000 test images: 97.3076923076923 %
# Accuracy of the network on the 10000 test images: 97.21428571428571 %
# Accuracy of the network on the 10000 test images: 97.33333333333333 %
# Accuracy of the network on the 10000 test images: 97.1875 %
# Accuracy of the network on the 10000 test images: 97.11764705882354 %
# Accuracy of the network on the 10000 test images: 97.05555555555556 %
# Accuracy of the network on the 10000 test images: 97.05263157894737 %
# Accuracy of the network on the 10000 test images: 97.05 %
# Accuracy of the network on the 10000 test images: 96.9047619047619 %
# Accuracy of the network on the 10000 test images: 96.77272727272727 %
# Accuracy of the network on the 10000 test images: 96.73913043478261 %
# Accuracy of the network on the 10000 test images: 96.83333333333333 %
# Accuracy of the network on the 10000 test images: 96.84 %
# Accuracy of the network on the 10000 test images: 96.92307692307692 %
# Accuracy of the network on the 10000 test images: 96.85185185185185 %
# Accuracy of the network on the 10000 test images: 96.96428571428571 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 96.96666666666667 %
# Accuracy of the network on the 10000 test images: 96.96774193548387 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 97.06060606060606 %
# Accuracy of the network on the 10000 test images: 97.1470588235294 %
# Accuracy of the network on the 10000 test images: 97.14285714285714 %
# Accuracy of the network on the 10000 test images: 97.05555555555556 %
# Accuracy of the network on the 10000 test images: 97.10810810810811 %
# Accuracy of the network on the 10000 test images: 97.02631578947368 %
# Accuracy of the network on the 10000 test images: 97.02564102564102 %
# Accuracy of the network on the 10000 test images: 97.025 %
# Accuracy of the network on the 10000 test images: 97.02439024390245 %
# Accuracy of the network on the 10000 test images: 97.02380952380952 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 97.02272727272727 %
# Accuracy of the network on the 10000 test images: 97.06666666666666 %
# Accuracy of the network on the 10000 test images: 97.06521739130434 %
# Accuracy of the network on the 10000 test images: 97.08510638297872 %
# Accuracy of the network on the 10000 test images: 97.08333333333333 %
# Accuracy of the network on the 10000 test images: 97.0204081632653 %
# Accuracy of the network on the 10000 test images: 97.04 %
# Accuracy of the network on the 10000 test images: 97.09803921568627 %
# Accuracy of the network on the 10000 test images: 97.15384615384616 %
# Accuracy of the network on the 10000 test images: 97.20754716981132 %
# Accuracy of the network on the 10000 test images: 97.24074074074075 %
# Accuracy of the network on the 10000 test images: 97.27272727272727 %
# Accuracy of the network on the 10000 test images: 97.32142857142857 %
# Accuracy of the network on the 10000 test images: 97.33333333333333 %
# Accuracy of the network on the 10000 test images: 97.34482758620689 %
# Accuracy of the network on the 10000 test images: 97.33898305084746 %
# Accuracy of the network on the 10000 test images: 97.3 %
# Accuracy of the network on the 10000 test images: 97.27868852459017 %
# Accuracy of the network on the 10000 test images: 97.30645161290323 %
# Accuracy of the network on the 10000 test images: 97.34920634920636 %
# Accuracy of the network on the 10000 test images: 97.390625 %
# Accuracy of the network on the 10000 test images: 97.43076923076923 %
# Accuracy of the network on the 10000 test images: 97.36363636363636 %
# Accuracy of the network on the 10000 test images: 97.3731343283582 %
# Accuracy of the network on the 10000 test images: 97.36764705882354 %
# Accuracy of the network on the 10000 test images: 97.40579710144928 %
# Accuracy of the network on the 10000 test images: 97.44285714285714 %
# Accuracy of the network on the 10000 test images: 97.47887323943662 %
# Accuracy of the network on the 10000 test images: 97.51388888888889 %
# Accuracy of the network on the 10000 test images: 97.53424657534246 %
# Accuracy of the network on the 10000 test images: 97.56756756756756 %
# Accuracy of the network on the 10000 test images: 97.58666666666667 %
# Accuracy of the network on the 10000 test images: 97.61842105263158 %
# Accuracy of the network on the 10000 test images: 97.64935064935065 %
# Accuracy of the network on the 10000 test images: 97.67948717948718 %
# Accuracy of the network on the 10000 test images: 97.68354430379746 %
# Accuracy of the network on the 10000 test images: 97.7 %
# Accuracy of the network on the 10000 test images: 97.70370370370371 %
# Accuracy of the network on the 10000 test images: 97.73170731707317 %
# Accuracy of the network on the 10000 test images: 97.74698795180723 %
# Accuracy of the network on the 10000 test images: 97.76190476190476 %
# Accuracy of the network on the 10000 test images: 97.7764705882353 %
# Accuracy of the network on the 10000 test images: 97.76744186046511 %
# Accuracy of the network on the 10000 test images: 97.79310344827586 %
# Accuracy of the network on the 10000 test images: 97.81818181818181 %
# Accuracy of the network on the 10000 test images: 97.84269662921348 %
# Accuracy of the network on the 10000 test images: 97.86666666666666 %
# Accuracy of the network on the 10000 test images: 97.85714285714286 %
# Accuracy of the network on the 10000 test images: 97.8804347826087 %
# Accuracy of the network on the 10000 test images: 97.89247311827957 %
# Accuracy of the network on the 10000 test images: 97.91489361702128 %
# Accuracy of the network on the 10000 test images: 97.92631578947369 %
# Accuracy of the network on the 10000 test images: 97.92708333333333 %
# Accuracy of the network on the 10000 test images: 97.89690721649484 %
# Accuracy of the network on the 10000 test images: 97.81632653061224 %
# Accuracy of the network on the 10000 test images: 97.81818181818181 %
# Accuracy of the network on the 10000 test images: 97.84 %
